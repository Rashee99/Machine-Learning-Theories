# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
cctv23 = pd.read_csv("data_cctv23.csv")
cctv23.sample(5)
# Out:
#       Ids            X           Y
# 2632   11  1150.566406  660.986938
# 7534   24   840.854248  502.058472
# 247     8   579.609131  356.184692
# 353     1   922.044067  542.049072
# 2945    6   471.414124  257.094818

# %%
for id_num in cctv23["Ids"]:
    plot_value = cctv23[cctv23['Ids']==id_num]
    plt.scatter(plot_value['X'], plot_value['Y'],s=1)
   
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("CCTV23")

# %%
from sklearn.cluster import AgglomerativeClustering

model = AgglomerativeClustering(n_clusters=2, affinity='euclidean', linkage='ward')
pred = model.fit_predict(cctv23[['X','Y']])
cctv23["Cluster"] = pred
# Out:
# c:\users\www\appdata\local\programs\python\python39\lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(

# %%
cctv23.sample(5)
# Out:
#        Ids           X           Y  Cluster
# 10068   40  423.577393  560.404297        1
# 10022    6  471.208771  257.292877        0
# 847      4  100.549294  186.714722        0
# 4244    19  510.925720  751.997925        1
# 2388    16  256.518890  203.297638        0

# %%
# Plot the clustered data
c1 = cctv23[cctv23['Cluster']==0]
c2 = cctv23[cctv23['Cluster']==1]

plt.scatter(c1['X'],c1['Y'],s=1)
plt.scatter(c2['X'],c2['Y'],s=1)
plt.xlabel("X coordination")
plt.ylabel("Y coordination")
plt.title("CCTV23 - Hierarchical Clustering linkage=ward, affinity=euclidean")
# Out:
# Text(0.5, 1.0, 'CCTV23 - Hierarchical Clustering linkage=ward, affinity=euclidean')

# %%
model = AgglomerativeClustering(n_clusters=2, affinity='cosine', linkage='complete')
pred = model.fit_predict(cctv23[['X','Y']])
cctv23["Cluster"] = pred
# Out:
# c:\users\www\appdata\local\programs\python\python39\lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(

# %%
# Plot the clustered data
c1 = cctv23[cctv23['Cluster']==0]
c2 = cctv23[cctv23['Cluster']==1]

plt.scatter(c1['X'],c1['Y'],s=1)
plt.scatter(c2['X'],c2['Y'],s=1)
plt.xlabel("X coordination")
plt.ylabel("Y coordination")
plt.title("CCTV23 - Hierarchical Clustering linkage=complete, affinity=cosine")
# Out:
# Text(0.5, 1.0, 'CCTV23 - Hierarchical Clustering linkage=complete, affinity=cosine')

# %%
model = AgglomerativeClustering(n_clusters=2, affinity='manhattan', linkage='single')
pred = model.fit_predict(cctv23[['X','Y']])
cctv23["Cluster"] = pred
# Out:
# c:\users\www\appdata\local\programs\python\python39\lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(

# %%
# Plot the clustered data
c1 = cctv23[cctv23['Cluster']==0]
c2 = cctv23[cctv23['Cluster']==1]

plt.scatter(c1['X'],c1['Y'],s=1)
plt.scatter(c2['X'],c2['Y'],s=1)
plt.xlabel("X coordination")
plt.ylabel("Y coordination")
plt.title("CCTV23 - Hierarchical Clustering linkage=single, affinity=manhatten")
# Out:
# Text(0.5, 1.0, 'CCTV23 - Hierarchical Clustering linkage=single, affinity=manhatten')

# %%
model = AgglomerativeClustering(n_clusters=2, affinity='euclidean', linkage='single')
pred = model.fit_predict(cctv23[['X','Y']])
cctv23["Cluster"] = pred
# Out:
# c:\users\www\appdata\local\programs\python\python39\lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(

# %%
# Plot the clustered data
c1 = cctv23[cctv23['Cluster']==0]
c2 = cctv23[cctv23['Cluster']==1]

plt.scatter(c1['X'],c1['Y'],s=1)
plt.scatter(c2['X'],c2['Y'],s=1)
plt.xlabel("X coordination")
plt.ylabel("Y coordination")
plt.title("CCTV23 - Hierarchical Clustering linkage=single, affinity=euclidean")
# Out:
# Text(0.5, 1.0, 'CCTV23 - Hierarchical Clustering linkage=single, affinity=euclidean')

# %%
model = AgglomerativeClustering(n_clusters=2, affinity='cosine', linkage='single')
pred = model.fit_predict(cctv23[['X','Y']])
cctv23["Cluster"] = pred
# Out:
# c:\users\www\appdata\local\programs\python\python39\lib\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(

# %%
# Plot the clustered data
c1 = cctv23[cctv23['Cluster']==0]
c2 = cctv23[cctv23['Cluster']==1]

plt.scatter(c1['X'],c1['Y'],s=1)
plt.scatter(c2['X'],c2['Y'],s=1)
plt.xlabel("X coordination")
plt.ylabel("Y coordination")
plt.title("CCTV23 - Hierarchical Clustering linkage=single, affinity=cosine")
# Out:
# Text(0.5, 1.0, 'CCTV23 - Hierarchical Clustering linkage=single, affinity=cosine')
